# %%
# 📊 Dashboard de Ventas - Visualización Interactiva
# Este notebook presenta un dashboard interactivo con los datos procesados en ClickHouse.
# **Tecnologías:**
# - **Plotly** - Gráficos interactivos
# - **ClickHouse** - Fuente de datos analíticos
# - **Pandas** - Manipulación de DataFrames

# %%
# Instalar dependencias si no están disponibles
# !pip install -q plotly clickhouse-connect pandas nbformat kaleido

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import clickhouse_connect
import pandas as pd
from datetime import datetime

# Configuración de Plotly para notebooks
import plotly.io as pio
pio.renderers.default = 'notebook'

print("✅ Librerías cargadas correctamente")
# Out:
# ✅ Librerías cargadas correctamente

# %%
# Conectar a ClickHouse
client = clickhouse_connect.get_client(
    host='clickhouse',
    port=8123,
    database='dw_analitico'
)

# Verificar conexión
result = client.query("SELECT COUNT(*) as total FROM ventas_resumen")
total_registros = result.result_rows[0][0]
print(f"✅ Conectado a ClickHouse")
print(f"📊 Total de registros en ventas_resumen: {total_registros:,}")
# Out:
# ✅ Conectado a ClickHouse
# 📊 Total de registros en ventas_resumen: 7,980

# %%
# Gráfico de barras horizontal - Top Categorías
fig_categorias = px.bar(
    df_categorias.sort_values('total_ventas', ascending=True),
    x='total_ventas',
    y='categoria',
    orientation='h',
    title='🏆 Ventas por Categoría',
    labels={'total_ventas': 'Ventas Totales ($)', 'categoria': 'Categoría'},
    color='total_ventas',
    color_continuous_scale='Viridis'
)

fig_categorias.update_layout(
    height=400,
    showlegend=False,
    xaxis_tickformat='$,.0f'
)

fig_categorias.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="1263ae8a-c7b5-4186-a956-7fd37e62fdeb" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1263ae8a-c7b5-4186-a956-7fd37e62fdeb")) {                    Plotly.newPlot(                        "1263ae8a-c7b5-4186-a956-7fd37e62fdeb",                        [{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3961114.22","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"3961114.22","orientation":"h","showlegend":true,"textposition":"auto","x":[3961114.22],"xaxis":"x","y":["Alimentos"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4056763.74","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"4056763.74","orientation":"h","showlegend":true,"textposition":"auto","x":[4056763.74],"xaxis":"x","y":["Musica"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4076437.19","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"4076437.19","orientation":"h","showlegend":true,"textposition":"auto","x":[4076437.19],"xaxis":"x","y":["Cine"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4100243.26","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"4100243.26","orientation":"h","showlegend":true,"textposition":"auto","x":[4100243.26],"xaxis":"x","y":["Juguetes"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4112477.04","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"4112477.04","orientation":"h","showlegend":true,"textposition":"auto","x":[4112477.04],"xaxis":"x","y":["Hogar"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4113339.42","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"4113339.42","orientation":"h","showlegend":true,"textposition":"auto","x":[4113339.42],"xaxis":"x","y":["Salud"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4139323.63","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"4139323.63","orientation":"h","showlegend":true,"textposition":"auto","x":[4139323.63],"xaxis":"x","y":["Electronica"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4146430.15","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"4146430.15","orientation":"h","showlegend":true,"textposition":"auto","x":[4146430.15],"xaxis":"x","y":["Deportes"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4149082.77","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"4149082.77","orientation":"h","showlegend":true,"textposition":"auto","x":[4149082.77],"xaxis":"x","y":["Ropa"],"yaxis":"y","type":"bar"},{"hovertemplate":"Ventas Totales ($)=%{x}\u003cbr\u003eCategoría=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4161815.88","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"41618 ...

# %%
# Gráfico de pastel - Distribución de Transacciones
fig_pie = px.pie(
    df_categorias,
    values='total_transacciones',
    names='categoria',
    title='📊 Distribución de Transacciones por Categoría',
    hole=0.4,
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig_pie.update_traces(textposition='inside', textinfo='percent+label')
fig_pie.update_layout(height=450)

fig_pie.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="5fab084e-9df8-4757-b65d-9e9ead1ad175" class="plotly-graph-div" style="height:450px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5fab084e-9df8-4757-b65d-9e9ead1ad175")) {                    Plotly.newPlot(                        "5fab084e-9df8-4757-b65d-9e9ead1ad175",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"categoria=%{label}\u003cbr\u003etotal_transacciones=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Mascotas","Jardin","Libros","Belleza","Videojuegos","Automotriz","Ropa","Deportes","Electronica","Salud","Hogar","Juguetes","Cine","Musica","Alimentos"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"u2","bdata":"OSZcJt4lECYqJocm9yXwJeMmsCWYJYslUCUGJaIk"},"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpo ...

# %%
# Gráfico de línea - Ventas diarias
fig_temporal = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    subplot_titles=('💵 Ventas Diarias', '🛒 Transacciones Diarias'),
    vertical_spacing=0.1
)

# Ventas
fig_temporal.add_trace(
    go.Scatter(
        x=df_temporal['fecha_venta'],
        y=df_temporal['ventas_diarias'],
        mode='lines+markers',
        name='Ventas',
        line=dict(color='#2ecc71', width=2),
        marker=dict(size=4)
    ),
    row=1, col=1
)

# Transacciones
fig_temporal.add_trace(
    go.Scatter(
        x=df_temporal['fecha_venta'],
        y=df_temporal['transacciones_diarias'],
        mode='lines+markers',
        name='Transacciones',
        line=dict(color='#3498db', width=2),
        marker=dict(size=4)
    ),
    row=2, col=1
)

fig_temporal.update_layout(
    title_text='📅 Tendencia Temporal de Ventas',
    height=500,
    showlegend=False
)

fig_temporal.update_yaxes(title_text="Ventas ($)", row=1, col=1)
fig_temporal.update_yaxes(title_text="# Transacciones", row=2, col=1)

fig_temporal.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="72cb0dc5-46da-4cfc-81c5-58058c14274c" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("72cb0dc5-46da-4cfc-81c5-58058c14274c")) {                    Plotly.newPlot(                        "72cb0dc5-46da-4cfc-81c5-58058c14274c",                        [{"line":{"color":"#2ecc71","width":2},"marker":{"size":4},"mode":"lines+markers","name":"Ventas","x":["2024-01-01T00:00:00.000000000","2024-01-02T00:00:00.000000000","2024-01-03T00:00:00.000000000","2024-01-04T00:00:00.000000000","2024-01-05T00:00:00.000000000","2024-01-06T00:00:00.000000000","2024-01-07T00:00:00.000000000","2024-01-08T00:00:00.000000000","2024-01-09T00:00:00.000000000","2024-01-10T00:00:00.000000000","2024-01-11T00:00:00.